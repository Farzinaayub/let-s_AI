# %%
import pandas as pd
import seaborn as sns

# %%
# importing the dataset
df = pd.read_csv('diamonds.csv')

# %%
df
# Out:
#      carat        cut color clarity  depth  table  price     x     y     z
# 0     0.24      Ideal     G    VVS1   62.1   56.0    559  3.97  4.00  2.47
# 1     0.58  Very Good     F    VVS2   60.0   57.0   2201  5.44  5.42  3.26
# 2     0.40      Ideal     E    VVS2   62.1   55.0   1238  4.76  4.74  2.95
# 3     0.43    Premium     E    VVS2   60.8   57.0   1304  4.92  4.89  2.98
# 4     1.55      Ideal     E     SI2   62.3   55.0   6901  7.44  7.37  4.61
# ..     ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 495   0.71  Very Good     H     SI2   62.2   55.1   2339  5.70  5.72  3.55
# 496   1.57      Ideal     I     SI1   62.2   56.0  10633  7.42  7.47  4.63
# 497   1.00      Ideal     I     SI1   62.7   56.0   4174  6.33  6.37  3.98
# 498   0.31      Ideal     F      IF   62.2   56.0    874  4.31  4.34  2.69
# 499   1.20    Premium     I     VS1   62.8   56.0   6021  6.80  6.74  4.25
#
# [500 rows x 10 columns]

# %%
# how are carat and price variables behaving against each other
# plot carat and price on the x-y plane
# Worked with graph sheets in school?
# scatterplot
# x, y -> plot points on the plane

sns.scatterplot(x = 'carat', y = 'price', data = df)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
df
# Out:
#      carat        cut color clarity  depth  table  price     x     y     z
# 0     0.24      Ideal     G    VVS1   62.1   56.0    559  3.97  4.00  2.47
# 1     0.58  Very Good     F    VVS2   60.0   57.0   2201  5.44  5.42  3.26
# 2     0.40      Ideal     E    VVS2   62.1   55.0   1238  4.76  4.74  2.95
# 3     0.43    Premium     E    VVS2   60.8   57.0   1304  4.92  4.89  2.98
# 4     1.55      Ideal     E     SI2   62.3   55.0   6901  7.44  7.37  4.61
# ..     ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 495   0.71  Very Good     H     SI2   62.2   55.1   2339  5.70  5.72  3.55
# 496   1.57      Ideal     I     SI1   62.2   56.0  10633  7.42  7.47  4.63
# 497   1.00      Ideal     I     SI1   62.7   56.0   4174  6.33  6.37  3.98
# 498   0.31      Ideal     F      IF   62.2   56.0    874  4.31  4.34  2.69
# 499   1.20    Premium     I     VS1   62.8   56.0   6021  6.80  6.74  4.25
#
# [500 rows x 10 columns]

# %%
sns.scatterplot(x = 'carat', y = 'price', data = df, hue = 'color')
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x = 'carat', y = 'price', data = df)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x = 'carat', y = 'price',data = df, hue = 'cut')

# hue = 'cut'
# allows for viz of carat and price and at the same time distinguishes between diamonds basis the cut category
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
df
# Out:
#      carat        cut color clarity  depth  table  price     x     y     z
# 0     0.24      Ideal     G    VVS1   62.1   56.0    559  3.97  4.00  2.47
# 1     0.58  Very Good     F    VVS2   60.0   57.0   2201  5.44  5.42  3.26
# 2     0.40      Ideal     E    VVS2   62.1   55.0   1238  4.76  4.74  2.95
# 3     0.43    Premium     E    VVS2   60.8   57.0   1304  4.92  4.89  2.98
# 4     1.55      Ideal     E     SI2   62.3   55.0   6901  7.44  7.37  4.61
# ..     ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 495   0.71  Very Good     H     SI2   62.2   55.1   2339  5.70  5.72  3.55
# 496   1.57      Ideal     I     SI1   62.2   56.0  10633  7.42  7.47  4.63
# 497   1.00      Ideal     I     SI1   62.7   56.0   4174  6.33  6.37  3.98
# 498   0.31      Ideal     F      IF   62.2   56.0    874  4.31  4.34  2.69
# 499   1.20    Premium     I     VS1   62.8   56.0   6021  6.80  6.74  4.25
#
# [500 rows x 10 columns]

# %%
# how are the diamonds behaving basis a 4th variable
# carat, price, cut
# clarity

sns.scatterplot(x = 'carat', y = 'price',data = df, hue = 'cut', size = 'clarity')
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
# histplot
# histogram
# looks similar to bar plot
# no gap between bars
# each bar/bin represents a range of values

# %%
sns.histplot(df['price'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
sns.histplot(df['price'], bins = 20)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
sns.histplot(df['price'], kde = True, bins = 20)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
sns.histplot(df['price'], kde = True)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
(df['price'] > 4500) & (df['price'] < 5500)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: price, Length: 500, dtype: bool

# %%
df[(df['price'] > 4500) & (df['price'] < 5500)]
# Out:
#      carat        cut color clarity  depth  table  price     x     y     z
# 9     1.14      Ideal     H     SI1   60.3   57.0   4789  6.79  6.85  4.11
# 54    0.90  Very Good     H    VVS2   61.8   60.0   4617  6.11  6.15  3.79
# 72    1.07    Premium     G     SI2   62.1   59.0   4584  6.54  6.48  4.04
# 94    1.01  Very Good     E     SI1   62.8   57.0   5411  6.35  6.39  4.00
# 103   1.09      Ideal     F     SI2   62.0   56.0   5306  6.62  6.58  4.09
# 110   1.12    Premium     I     SI1   60.8   57.0   4704  6.76  6.70  4.09
# 114   1.00       Good     D     SI1   65.1   54.0   4786  6.23  6.27  4.07
# 115   1.01    Premium     H     VS2   61.5   59.0   5303  6.48  6.49  3.99
# 120   1.11      Ideal     H     SI1   61.6   56.0   5456  6.69  6.65  4.11
# 144   1.11      Ideal     H     SI2   62.7   57.0   4578  6.59  6.66  4.14
# 146   1.02    Premium     E     SI1   62.8   58.0   5429  6.45  6.39  4.03
# ...

# %%
len(df[(df['price'] > 4500) & (df['price'] < 5500)])
# Out:
# 41

# %%
# When to use a histplot
# To understand the distribution of values of a given variable
# to understand underlying patters, outliers etc

# %%
# average price values of diamonds of each color

df.groupby('color')['price'].mean()
# Out:
# color
# D    2815.562500
# E    3060.045872
# F    3991.961165
# G    4557.275510
# H    5162.026667
# I    6197.651163
# J    5907.958333
# Name: price, dtype: float64

# %%
df
# Out:
#      carat        cut color clarity  depth  table  price     x     y     z
# 0     0.24      Ideal     G    VVS1   62.1   56.0    559  3.97  4.00  2.47
# 1     0.58  Very Good     F    VVS2   60.0   57.0   2201  5.44  5.42  3.26
# 2     0.40      Ideal     E    VVS2   62.1   55.0   1238  4.76  4.74  2.95
# 3     0.43    Premium     E    VVS2   60.8   57.0   1304  4.92  4.89  2.98
# 4     1.55      Ideal     E     SI2   62.3   55.0   6901  7.44  7.37  4.61
# ..     ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 495   0.71  Very Good     H     SI2   62.2   55.1   2339  5.70  5.72  3.55
# 496   1.57      Ideal     I     SI1   62.2   56.0  10633  7.42  7.47  4.63
# 497   1.00      Ideal     I     SI1   62.7   56.0   4174  6.33  6.37  3.98
# 498   0.31      Ideal     F      IF   62.2   56.0    874  4.31  4.34  2.69
# 499   1.20    Premium     I     VS1   62.8   56.0   6021  6.80  6.74  4.25
#
# [500 rows x 10 columns]

# %%
# bar plot
# calculate avg price value of diamonds of each color
# How many variables? -> 2 (color and price)

sns.barplot(x = 'color', y = 'price', data = df )
# Out:
# <AxesSubplot:xlabel='color', ylabel='price'>

# %%
df.groupby('color')['price'].mean()
# Out:
# color
# D    2815.562500
# E    3060.045872
# F    3991.961165
# G    4557.275510
# H    5162.026667
# I    6197.651163
# J    5907.958333
# Name: price, dtype: float64

# %%
# average price of diamonds for every cut and color

sns.barplot(x = 'color', y = 'price', data = df , hue = 'cut')
# Out:
# <AxesSubplot:xlabel='color', ylabel='price'>

# %%
# bar plot?
# Comparison of a continuous variable across different categories -> color and cut
# Visualize aggregated data against categories

# %%
# visualize distribution of price values against each cut category
# check for outliers, how price is distributed actoss the median and different quartile ranges

# %%
# box plot

# %%
sns.boxplot(x = 'cut', y = 'price', data = df)
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %%
# what is quartiles of data?
# How many quartiles?
# 3 quartiles
# 1 -> 25th percentile
# 2 -> 50th percentile (median / middle value)
# 3 -> 75th percentile

# %%
# distribution of prices against every category and color

sns.boxplot(x = 'cut', y = 'price', data = df, hue = 'color')
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %%
sns.stripplot(x = 'cut', y = 'price', data = df, hue = 'color')
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %%
# viz relationship between a continuous and a categorical variable

# Strip plot is a type of categorical scatter plot
# scatter plots-> plot continuous variables on both axes

# %%
sns.stripplot(x = 'cut', y = 'price', data = df, hue = 'color', dodge = True)
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %%
# Viz relationship between all numerical variables

df
# Out:
#      carat        cut color clarity  depth  table  price     x     y     z
# 0     0.24      Ideal     G    VVS1   62.1   56.0    559  3.97  4.00  2.47
# 1     0.58  Very Good     F    VVS2   60.0   57.0   2201  5.44  5.42  3.26
# 2     0.40      Ideal     E    VVS2   62.1   55.0   1238  4.76  4.74  2.95
# 3     0.43    Premium     E    VVS2   60.8   57.0   1304  4.92  4.89  2.98
# 4     1.55      Ideal     E     SI2   62.3   55.0   6901  7.44  7.37  4.61
# ..     ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 495   0.71  Very Good     H     SI2   62.2   55.1   2339  5.70  5.72  3.55
# 496   1.57      Ideal     I     SI1   62.2   56.0  10633  7.42  7.47  4.63
# 497   1.00      Ideal     I     SI1   62.7   56.0   4174  6.33  6.37  3.98
# 498   0.31      Ideal     F      IF   62.2   56.0    874  4.31  4.34  2.69
# 499   1.20    Premium     I     VS1   62.8   56.0   6021  6.80  6.74  4.25
#
# [500 rows x 10 columns]

# %%
# pairplot

sns.pairplot(df)

# df -> 20 columns -> 12 numerical 
# pairplot of above df? -> 12*12 -> 144

# %%
# correlation between numerical variables/columns of df

# %%
# How is 1 variable behaving when a different variable is changing (increasing / decreasing)
# x = y

# x has increased by 2 units
# y will also increase by 2 units

# %%
# x = -0.2 y

# %%
# if y increases by 2 units -> correction from class
# x would? -> decrease by 0.4 units

# %%
df.corr()
# Out:
#           carat     depth     table     price         x         y         z
# carat  1.000000 -0.044261  0.179642  0.926961  0.979401  0.979099  0.977348
# depth -0.044261  1.000000 -0.364495 -0.045704 -0.087650 -0.086307  0.028299
# table  0.179642 -0.364495  1.000000  0.131927  0.196010  0.192696  0.154183
# price  0.926961 -0.045704  0.131927  1.000000  0.888455  0.891607  0.887927
# x      0.979401 -0.087650  0.196010  0.888455  1.000000  0.998019  0.992200
# y      0.979099 -0.086307  0.192696  0.891607  0.998019  1.000000  0.992903
# z      0.977348  0.028299  0.154183  0.887927  0.992200  0.992903  1.000000

# %%
df
# Out:
#      carat        cut color clarity  depth  table  price     x     y     z
# 0     0.24      Ideal     G    VVS1   62.1   56.0    559  3.97  4.00  2.47
# 1     0.58  Very Good     F    VVS2   60.0   57.0   2201  5.44  5.42  3.26
# 2     0.40      Ideal     E    VVS2   62.1   55.0   1238  4.76  4.74  2.95
# 3     0.43    Premium     E    VVS2   60.8   57.0   1304  4.92  4.89  2.98
# 4     1.55      Ideal     E     SI2   62.3   55.0   6901  7.44  7.37  4.61
# ..     ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 495   0.71  Very Good     H     SI2   62.2   55.1   2339  5.70  5.72  3.55
# 496   1.57      Ideal     I     SI1   62.2   56.0  10633  7.42  7.47  4.63
# 497   1.00      Ideal     I     SI1   62.7   56.0   4174  6.33  6.37  3.98
# 498   0.31      Ideal     F      IF   62.2   56.0    874  4.31  4.34  2.69
# 499   1.20    Premium     I     VS1   62.8   56.0   6021  6.80  6.74  4.25
#
# [500 rows x 10 columns]

# %%
# heatmap
# map representing different values with colors
# extreme dark when positive corr
# extreme light when neg corr
# a color of some middle shade when value lies somewhere in between

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(), annot = True, cmap = 'coolwarm')
# Out:
# <AxesSubplot:>
